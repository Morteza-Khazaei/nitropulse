# %%
from inversion import S1Data

# %%
risma_ids = ['MB1', 'MB2', 'MB3', 'MB4', 'MB5', 'MB6', 'MB7', 'MB8', 'MB9', 'MB10',
             'MB11', 'MB12', 'MB13', 'MB14', 'MB15']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
s1 = S1Data(workspace_dir='../assets', auto_download=False)
s1.download_S1_data(
    stations=risma_ids, buffer_distance=20, 
    start_date='2010-01-01', end_date='2024-01-01', 
    gee_project_id='ee-mortezakhazaei1370', roi_asset_id='RISMA_Stations_Canada')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found GEE folder: S1_CSV_files
# S1_CSV folder already exists: ../assets/inputs/S1_CSV_files
# Hello from the Earth Engine servers!
# The file '../assets/inputs/S1_CSV_files/RISMA_MB1_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB1_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB2_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB2_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB3_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB3_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB4_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB4_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB5_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB5_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB6_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB6_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB7_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB7_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB8_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB8_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB9_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB9_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB10_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB10_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB11_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB11_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB12_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB12_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB13_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB13_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB14_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB14_2010_to_2024_buffer20m.
# The file '../assets/inputs/S1_CSV_files/RISMA_MB15_2010_to_2024_buffer20m.csv' exists.
# 	Skipping download process for RISMA_MB15_2010_to_2024_buffer20m.

# %%
df = s1.load_df()
print(df.shape)
df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 	Processing file: RISMA_MB1_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB2_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB3_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB4_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB5_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB6_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB7_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB8_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB9_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB10_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB11_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB12_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB13_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB14_2010_to_2024_buffer20m.csv
# 	Processing file: RISMA_MB15_2010_to_2024_buffer20m.csv
# (6110, 9)
# band  index  op  year  doy    VH    VV  angle   lc station
# 0         0   0  2015  115 -20.0 -13.0   40.0  146     MB1
# 1         1   0  2015  127 -18.0 -12.0   40.0  146     MB1
# 2         2   0  2015  139 -17.0 -10.0   40.0  146     MB1
# 3         3   0  2015  146 -18.0 -12.0   31.0  146     MB1
# 4         4   0  2015  158 -16.0  -9.0   31.0  146     MB1
